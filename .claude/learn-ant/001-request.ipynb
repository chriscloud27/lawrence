# %%
# Install dependencies
python3 install anthropic python-dotenv
# Out:
#   Cell In[4], line 2
#     python 3 -m pip install anthropic python-dotenv
#            ^
# SyntaxError: invalid syntax

# %%
# Load 
from dotenv import load_dotenv
load_dotenv

# %%
# Create API client
from anthropic import Anthropic 
client = Anthropic()
model = "claude-sonnet-4-0"

# %%
def add_user_message(messages, text ):
    user_message = {
        "role": "user",
        "content": text
    }
    messages.append(user_message) 

def add_assistant_message(messages, text ):
    assistant_message = {
        "role": "assistant",
        "content": text
    }
    messages.append(assistant_message) 

def chat(messages): 
    client.message.create( 
        model = model,
        max_token = 1000,
        messages=messages
)
    return message.content[0].text

# %%
# init conversation
messages = []

# Ask init question
add_user_message(messages, "What is quantum computing?")

# Pass the list of messages into a 'chat'
answer = chat(messages)

# Take the answer and add it as an assistant message to our list of messages
add_assistant_message(messages, answer)

# Add the user's follow-up question to the list of messages
add_user_message(messages, "What are the benefits of quantum computing?")

# Pass the updated list of messages into a 'chat'
answer = chat(messages)

# %%
# messages in while and input
messages = []
while True:
    user_input = input("> ")
    print(">", user_input)

    # Add user message to messages
    add_user_message(messages, user_input)

    # Receive an answer
    answer = chat(messages)

    # Add assistant message to messages
    add_assistant_message(messages, answer)

    # Print the generated text
    print("----")
    print(answer)
    print("----")
